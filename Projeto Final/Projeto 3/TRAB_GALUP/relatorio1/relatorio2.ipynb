# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd

# %%
filename = '../relatorio2/questao1/rot2q1.txt'
data = pd.read_csv(filename, sep='\t', header=0)

# %%
ids = data['ID'][50:]
vgb = data['VGB'][50:]
lnid = np.log(ids)

print(ids.iloc[72], ids.iloc[73])

dydx = np.diff(lnid)/np.diff(vgb)
mmax = max(dydx)
x = dydx[(dydx>((mmax*0.531)-0.4)) & (dydx<((mmax*0.531)+0.4))]
# print(vgb.iloc[73], dydx[73])
x0 = 1.22015
# y0 = 8.08289021
y0 = ids.iloc[72]
x1 = 1.23014
# y1 = 7.79135858
y1 = ids.iloc[73]
# y = 7.95971676
x = 1.2243708207922415
k1 = x - x0
k2 = x1 - x0
vto_ = (k1/k2)*(y1-y0) + y0
print('\t', vto_/0.88)
plt.figure(0)
plt.plot(vgb[0:-1], dydx)
plt.plot(vgb.iloc[72], dydx[72], 'ro')
plt.show()
# Out:
# 1.2460500000000001e-06 1.35084e-06
# 	 1.4662775628832218e-06
# <img src="data:image/png;base64,..." width="640">
